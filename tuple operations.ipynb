# %%
#1 accessing tuple elements
student=("shaistha",21,"AI",89)
print(student[1])

#negative indexing
print(student[-1])
# Out:
# 21
# 89

# %%
#2 slicing tuples
age=(21,23,24,25,25,26,27,28,29)
print(age[1:4])
# Out:
# (23, 24, 25)

# %%
#3 immutability
student=("shaistha",21,"AI",89)
#student[0]="anu"
print(student)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 #3 immutability
#       2 student=("shaistha",21,"AI",89)
# ----> 3 student[0]="anu"
#       4 print(student)
#
# TypeError: 'tuple' object does not support item assignment

# %%
#4 looping through tupes
skills=("python","sql","ai")
f=(143,234,5,6,7,8,9)
for u in f:
    print(u,f.index(u))
# Out:
# 143 0
# 234 1
# 5 2
# 6 3
# 7 4
# 8 5
# 9 6

# %%
#5 tuple length
print(len(f))
# Out:
# 7

# %%
#6 check existence
print("python" in skills)
# Out:
# True

# %%
#7 count values
numbers=(1,1,2,3)
print(numbers.count(1))
# Out:
# 2

# %%
#8 find index
print(skills.index("sql"))
# Out:
# 1

# %%
#9 single element tuple
t=(5,)

# %%
#10 tuple packing
student="rahul",21,"AI"
print(student)
# Out:
# ('rahul', 21, 'AI')

# %%
#11 tuple unpacking
name,age,role=student
print(name)
print(age)
print(role)
# Out:
# rahul
# 21
# AI

# %%
#12 function return  example
def get_numbers():
    return("rahul",21)
data=get_numbers()
print(data)
# Out:
# ('rahul', 21)

# %%
#13 directly 
name,age=get_numbers()
print(get_numbers())
# Out:
# ('rahul', 21)

# %%
#14 nested tuples
students=(
    ("rahul",21),
    ("anu",22)

)
print(students)
# Out:
# (('rahul', 21), ('anu', 22))

# %%
#15 access nested tuples
print(students[0][0])
# Out:
# rahul

# %%
#16 convert list to tuple
skills=("python","sql")
skills_tuple=tuple(skills)
print(skills_tuple)
# Out:
# ('python', 'sql')

# %%
# tuple to list
skills_list=list(skills_tuple)
print(skills_list)
# Out:
# ['python', 'sql']

# %%
#17 tuple concatenation
t1=(1,2,3,4,5,6)
t2=(5,6,7)
print(t1+t2)
# Out:
# (1, 2, 3, 4, 5, 6, 5, 6, 7)

# %%
#18 tuple repeatition
t3=t1*2
print(t3)
# Out:
# (1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6)
